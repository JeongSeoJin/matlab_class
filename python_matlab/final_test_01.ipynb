# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import *
from scipy.integrate import *

# %% Pb. 1-(1)

import numpy as np
from scipy.integrate import *

def integrand(x, y):
    return x**2 * np.sin(x * y) - np.cos(y)

result, error = dblquad(integrand, 0, 3, lambda y: -1, lambda y: 2)
print("1. Double Integral Result:")
print(result)
# Out:
# 1. Double Integral Result:
# 1.0932722236117698

# %%
# %% Pb. 2-(1)

A = np.array([
    [1, 3, -2, 2],
    [0, 2.1, 1, 4],
    [7, -5, 2, 9]
])

B = np.array([
    [-2.1, 4],
    [0.3, 1],
    [5, -0.8],
    [1, 2]
])

AB = np.dot(A, B)
print("\n2-(1). Matrix AB Result:")
print(AB)
# Out:
# 2-(1). Matrix AB Result:
# [[-9.2  12.6 ]
#  [ 9.63  9.3 ]
#  [ 2.8  39.4 ]]

# %%
# %% Pb. 2-(2)

row_A3 = A[2, :]
col_B2 = B[:, 1]
dot_product = np.dot(row_A3, col_B2)
print("\n2-(2). Dot Product of A's 3rd Row and B's 2nd Column:")
print(dot_product)
# Out:
# 2-(2). Dot Product of A's 3rd Row and B's 2nd Column:
# 39.4

# %%
# %% Pb. 2-(1)

A = np.array([
    [1, 3, -2, 2],
    [0, 2.1, 1, 4],
    [7, -5, 2, 9]
])

B = np.array([
    [-2.1, 4],
    [0.3, 1],
    [5, -0.8],
    [1, 2]
])

AB = np.dot(A, B)
print("\n2-(1). Matrix AB Result: {}".format(AB))
# Out:
# 2-(1). Matrix AB Result: [[-9.2  12.6 ]
#  [ 9.63  9.3 ]
#  [ 2.8  39.4 ]]

# %%
# %% Pb. 2-(2)

row_A3 = A[2, :]
col_B2 = B[:, 1]
dot_product = np.dot(row_A3, col_B2)
print("\n2-(2). Dot Product of A's 3rd Row and B's 2nd Column:")
print(dot_product)
# Out:
# 2-(2). Dot Product of A's 3rd Row and B's 2nd Column:
# 39.4

# %%
# %% Pb. 2-(3)

C = B[0:3, :]  # First three rows of B
C_T = C.T
C_T_A = np.dot(C_T, A)
print("\n2-(3). Matrix C^T A Result:")
print(C_T_A)
# Out:
# 2-(3). Matrix C^T A Result:
# [[ 32.9  -30.67  14.5   42.  ]
#  [ -1.6   18.1   -8.6    4.8 ]]

# %%
# %% Pb. 2-(3)

C = B[1:3, :]  # First three rows of B
C_T = C.T
C_T_A = np.dot(C_T, A)
CTA = np.dot(np.transpose(C), A)
print("\n2-(3). Matrix C^T A Result:")
print(C_T_A)
print(CTA)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /home/seojin/Documents/matlab_ws/python_matlab/final_test_01.py:4
#       2 C = B[1:3, :]  # First three rows of B
#       3 C_T = C.T
# ----> 4 C_T_A = np.dot(C_T, A)
#       5 CTA = np.dot(np.transpose(C), A)
#       6 print("\n2-(3). Matrix C^T A Result:")
#
# File <__array_function__ internals>:200, in dot(*args, **kwargs)
#
# ValueError: shapes (2,2) and (3,4) not aligned: 2 (dim 1) != 3 (dim 0)

# %%
# %% Pb. 3-(1)

import numpy as np
import matplotlib.pyplot as plt

# 행렬 B 정의
B = np.array([
    [-2.1, 4],
    [0.3, 1],
    [5, -0.8],
    [1, 2]
])

# (1) 네 번째 행 벡터의 유클리드 노름 계산
vector_4th = B[3, :]  # B의 4번째 행
norm_4th = np.linalg.norm(vector_4th)  # 유클리드 노름 계산
print("3-(1). Fourth Row Vector Norm:")
print(norm_4th)  # 결과 출력
# Out:
# 3-(1). Fourth Row Vector Norm:
# 2.23606797749979

# %%
# %% Pb. 3-(2)

# (2) 점을 연결하는 그래프 그리기 및 거리 계산
# 원점을 포함한 점 집합 생성
points = np.vstack(([0, 0], B))  # 원점을 포함한 점들

# 각 점의 거리 계산
distances = []
for i in range(len(points)):
    for j in range(i + 1, len(points)):
        distance = np.linalg.norm(points[i] - points[j])
        distances.append((i, j, distance))  # 점의 인덱스와 거리 저장

# 거리 출력
print("\n3-(2). Distances between Points:")
for d in distances:
    print(f"Distance between Point {d[0]} and Point {d[1]}: {d[2]:.4f}")

# 그래프 그리기
plt.figure(figsize=(8, 8))
plt.grid(True)

# 점 표시
for i, (x, y) in enumerate(points):
    plt.scatter(x, y, label=f"Point {i} ({x}, {y})")
    plt.text(x + 0.1, y, f"{i}", fontsize=9)  # 점 인덱스 표시

# 점 간 연결선 그리기
for i in range(len(points)):
    for j in range(i + 1, len(points)):
        x_values = [points[i][0], points[j][0]]
        y_values = [points[i][1], points[j][1]]
        plt.plot(x_values, y_values, 'k--', linewidth=0.8)  # 점선 연결

# 그래프 설정
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
plt.title("Graph of Points and Distances")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend()
plt.show()
# Out:
# 3-(2). Distances between Points:
# Distance between Point 0 and Point 1: 4.5177
# Distance between Point 0 and Point 2: 1.0440
# Distance between Point 0 and Point 3: 5.0636
# Distance between Point 0 and Point 4: 2.2361
# Distance between Point 1 and Point 2: 3.8419
# Distance between Point 1 and Point 3: 8.5703
# Distance between Point 1 and Point 4: 3.6892
# Distance between Point 2 and Point 3: 5.0329
# Distance between Point 2 and Point 4: 1.2207
# Distance between Point 3 and Point 4: 4.8826

# %%
# %% Pb. 3-(2)

origin = np.array([0, 0])  # 원점
distances = []  # 거리 저장 리스트

plt.figure(figsize=(8, 8))
plt.grid(True)

# 각 점을 그래프에 표시하고, 원점과 연결
for i, (x, y) in enumerate(B):
    point = np.array([x, y])  # 현재 점
    distance = np.linalg.norm(point - origin)  # 원점과의 거리
    distances.append(distance)  # 거리 저장
    
    # 점과 선분 그리기
    plt.scatter(x, y, label=f"Point {i+1} ({x}, {y})")  # 점 표시
    plt.plot([origin[0], x], [origin[1], y], 'k--', linewidth=0.8)  # 원점과의 선분

    # 거리 정보 출력
    print(f"Distance between Origin and Point {i+1}: {distance:.4f}")

# 원점 표시
plt.scatter(0, 0, color='red', label="Origin (0, 0)")

# 그래프 설정
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.title("Graph of Points and Distances from Origin")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend()
plt.show()
# Out:
# Distance between Origin and Point 1: 4.5177
# Distance between Origin and Point 2: 1.0440
# Distance between Origin and Point 3: 5.0636
# Distance between Origin and Point 4: 2.2361

# %%
print(A)
# Out:
# [[ 1.   3.  -2.   2. ]
#  [ 0.   2.1  1.   4. ]
#  [ 7.  -5.   2.   9. ]]

# %%
# %% Pb. 3-(1)

import numpy as np
import matplotlib.pyplot as plt

# 행렬 B 정의
B = np.array([
    [-2.1, 4],
    [0.3, 1],
    [5, -0.8],
    [1, 2]
])

# (1) 네 번째 행 벡터의 유클리드 노름 계산
vector_4th = B[3, :]  # B의 4번째 행
norm_4th = np.linalg.norm(vector_4th)  # 유클리드 노름 계산
print("3-(1). Fourth Row Vector Norm:")
print(norm_4th)  # 결과 출력
# Out:
# 3-(1). Fourth Row Vector Norm:
# 2.23606797749979

# %%
# %% Pb. 2-(3)

C = B[0:3, :]  # First three rows of B
C_T = C.T
C_T_A = np.dot(C_T, A)
CTA = np.dot(np.transpose(C), A)
print("\n2-(3). Matrix C^T A Result:")
print(C_T_A)
print(CTA)
# Out:
# 2-(3). Matrix C^T A Result:
# [[ 32.9  -30.67  14.5   42.  ]
#  [ -1.6   18.1   -8.6    4.8 ]]
# [[ 32.9  -30.67  14.5   42.  ]
#  [ -1.6   18.1   -8.6    4.8 ]]

# %%
# %% Pb. 3-(2)

origin = np.array([0, 0])  # 원점
distances = []  # 거리 저장 리스트

plt.figure(figsize=(8, 8))
plt.grid(True)

# 각 점을 그래프에 표시하고, 원점과 연결
for i, (x, y) in enumerate(B):
    point = np.array([x, y])  # 현재 점
    distance = np.linalg.norm(point - origin)  # 원점과의 거리
    distances.append(distance)  # 거리 저장
    
    # 점과 선분 그리기
    plt.scatter(x, y, label=f"Point {i+1} ({x}, {y})")  # 점 표시
    plt.plot([origin[0], x], [origin[1], y], 'k--', linewidth=0.8)  # 원점과의 선분

    # 거리 정보 출력
    print(f"Distance between Origin and Point {i+1}: {distance:.4f}")

# 원점 표시
plt.scatter(0, 0, color='red', label="Origin (0, 0)")

# 그래프 설정
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.title("Graph of Points and Distances from Origin")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend()
plt.show()
# Out:
# Distance between Origin and Point 1: 4.5177
# Distance between Origin and Point 2: 1.0440
# Distance between Origin and Point 3: 5.0636
# Distance between Origin and Point 4: 2.2361

# %%
# %%

import numpy as np
import matplotlib.pyplot as plt

# 주어진 행렬 B
B = np.array([[-2.1,  4.0],
              [ 0.3,  1.0],
              [ 5.0, -0.8],
              [ 1.0,  2.0]])

# (1) B 행렬의 4번째 행 벡터 [1.0, 2.0]의 유클리드 놈 계산
fourth_row = B[3]  # B의 4번째 행
norm_value = np.linalg.norm(fourth_row)
print("4번째 행 벡터의 유클리드 놈:", norm_value)  # √(1² + 2²) = √5 ≈ 2.236

# (2) 그래프 그리기
# 원점과 각 점들을 연결하고, 각 점들 사이의 선분을 그린다.
# 또한 각 점까지의 거리(원점으로부터의 거리)와 점들 사이 거리 계산

fig, ax = plt.subplots()

# 원점
origin = np.array([0, 0])

# 원점에서 각 점까지의 거리 출력 및 선분 그리기
for i, point in enumerate(B):
    # 원점과 현재 점을 연결하는 선분
    ax.plot([origin[0], point[0]], [origin[1], point[1]], 'k--', alpha=0.5)
    
    # 원점에서 현재 점까지의 거리
    dist_from_origin = np.linalg.norm(point - origin)
    print(f"점 {i+1}번 {point}까지의 원점으로부터 거리: {dist_from_origin:.4f}")
    
    # 그래프에 점 표시
    ax.plot(point[0], point[1], 'bo')
    ax.text(point[0], point[1], f" P{i+1}", fontsize=9, ha='right')

# 점들 사이 거리 계산 및 선분 그리기 (총 4개의 점이므로 3개의 선분)
for i in range(len(B)-1):
    p1, p2 = B[i], B[i+1]
    distance = np.linalg.norm(p2 - p1)
    print(f"점 {i+1}과 점 {i+2} 사이 거리: {distance:.4f}")
    
    # 점들 사이를 연결하는 선분
    ax.plot([p1[0], p2[0]], [p1[1], p2[1]], 'r-')

# 그래프 설정
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('B 행렬의 점들 및 거리')
ax.grid(True)
ax.axhline(0, color='black', linewidth=1)  # x축 표시선
ax.axvline(0, color='black', linewidth=1)  # y축 표시선
plt.show()
# Out:
# 4번째 행 벡터의 유클리드 놈: 2.23606797749979
# 점 1번 [-2.1  4. ]까지의 원점으로부터 거리: 4.5177
# 점 2번 [0.3 1. ]까지의 원점으로부터 거리: 1.0440
# 점 3번 [ 5.  -0.8]까지의 원점으로부터 거리: 5.0636
# 점 4번 [1. 2.]까지의 원점으로부터 거리: 2.2361
# 점 1과 점 2 사이 거리: 3.8419
# 점 2과 점 3 사이 거리: 5.0329
# 점 3과 점 4 사이 거리: 4.8826
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 54665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 47148 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 51032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 51216 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 46308 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 48143 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 44144 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 47532 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 54665 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 47148 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 51032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 51216 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 46308 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 48143 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 44144 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 47532 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# %% Pb. 3-(2)

origin = np.array([0, 0])  # 원점
distances = []  # 거리 저장 리스트

plt.figure(figsize=(8, 8))
plt.grid(True)

# 각 점을 그래프에 표시하고, 원점과 연결
for i, (x, y) in enumerate(B):
    point = np.array([x, y])  # 현재 점
    distance = np.linalg.norm(point - origin)  # 원점과의 거리
    distances.append(distance)  # 거리 저장
    
    # 점과 선분 그리기
    plt.scatter(x, y, label=f"Point {i+1} ({x}, {y})")  # 점 표시
    plt.plot([origin[0], x], [origin[1], y], 'k--', linewidth=0.8)  # 원점과의 선분

    # 거리 정보 출력
    print(f"Distance between Origin and Point {i+1}: {distance:.4f}")

# 원점 표시
plt.scatter(0, 0, color='red', label="Origin (0, 0)")

# 그래프 설정
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.title("Graph of Points and Distances from Origin")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend()
plt.show()
# Out:
# Distance between Origin and Point 1: 4.5177
# Distance between Origin and Point 2: 1.0440
# Distance between Origin and Point 3: 5.0636
# Distance between Origin and Point 4: 2.2361
